# %%
import pandas as pd

# %%
# Showcase ability to navigate through DataFrames using Loc/Iloc
# Filter and Slice DataFrames
# Create and access groupby objects
# How to Sort DataFrames

# %%
data = pd.read_csv('movies.csv')
data.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm         ...           IMDB_norm  RT_norm_round  \
# ...

# %%
# Finding movies with greater than an IMDB rating of 7
print(data.loc[data['IMDB'] >= 7,['FILM','IMDB','IMDB_norm','IMDB_norm_round','IMDB_user_vote_count']].head())

# %%
# Movies with Less than 20k votes and Higher than a rating of 7
print(data.loc[(data['IMDB_user_vote_count']<20000) & (data['IMDB']>7),['FILM','IMDB','IMDB_user_vote_count']].head())
# Out:
#                                  FILM  IMDB  IMDB_user_vote_count
# 8        Shaun the Sheep Movie (2015)   7.4                 12227
# 9                 Love & Mercy (2015)   7.8                  5367
# 10  Far From The Madding Crowd (2015)   7.2                 12129
# 20              McFarland, USA (2015)   7.5                 13769
# 29         The End of the Tour (2015)   7.9                  1320

# %%
#Cleaning a Dataset
crime = pd.read_csv('crime.csv')
print(crime.count())
# Out:
# Address              37365
# Case Number          41032
# Crime Against        41032
# Neighborhood         39712
# Number of Records    41032
# Occur Date           41032
# Occur Month Year     41032
# Occur Time           41032
# Offense Category     41032
# Offense Count        41032
# Offense Type         41032
# Open Data Lat        36712
# Open Data Lon        36712
# Open Data X          36712
# Open Data Y          36712
# Report Date          41032
# Report Month Year    41032
# dtype: int64

# %%
crime = crime.dropna(how='any')
crime.count()
# Out:
# Address              36146
# Case Number          36146
# Crime Against        36146
# Neighborhood         36146
# Number of Records    36146
# Occur Date           36146
# Occur Month Year     36146
# Occur Time           36146
# Offense Category     36146
# Offense Count        36146
# Offense Type         36146
# Open Data Lat        36146
# Open Data Lon        36146
# Open Data X          36146
# Open Data Y          36146
# Report Date          36146
# Report Month Year    36146
# dtype: int64

# %%
# Condensing Offense Type to Common Categories
print(crime['Offense Type'].unique())
crime['Offense Type'] = crime['Offense Type'].replace({'Identity Theft':'Theft','Credit Card/ATM Fraud':'Fraud',
                                                       'Shoplifting':'Theft','Theft From Motor Vehicle':'Theft',
                                                       'Motor Vehicle Theft':'Theft','Burglary':'Theft',
                                                       'Theft of Motor Vehicle Parts or Accessories':'Theft',
                                                       'Theft From Building':'Theft','Robbery':'Theft',
                                                       'Theft From Coin-Operated Machine or Device':'Theft',
                                                       'Pocket-Picking':'Theft','Stolen Property Offenses':'Theft',
                                                       'Purse-Snatching':'Theft', 'Wire Fraud':'Fraud','Welfare Fraud':'Fraud',
                                                      'Drug/Narcotic Violations':'Violations','Weapons Law Violations':'Violations',
                                                      'Drug Equipment Violations':'Violations','Counterfeiting/Forgery':'Fraud',
                                                      'Prostitution':'Sex Crimes','Pornography/Obscene Material':'Sex Crimes',
                                                      'Assisting or Promoting Prostitution':'Sex Crimes','Commercial Sex Acts':'Sex Crimes',
                                                      'Impersonation':'Fraud'})
print('--------------------------------------------------------------------------------------------')
print(crime['Offense Type'].unique())
# Out:
# ['False Pretenses/Swindle/Confidence Game' 'Identity Theft'
#  'Credit Card/ATM Fraud' 'Embezzlement' 'Shoplifting' 'All Other Larceny'
#  'Theft From Motor Vehicle' 'Motor Vehicle Theft' 'Burglary'
#  'Theft of Motor Vehicle Parts or Accessories' 'Counterfeiting/Forgery'
#  'Vandalism' 'Theft From Building' 'Robbery' 'Aggravated Assault'
#  'Theft From Coin-Operated Machine or Device' 'Intimidation'
#  'Simple Assault' 'Hacking/Computer Invasion' 'Drug/Narcotic Violations'
#  'Pocket-Picking' 'Stolen Property Offenses' 'Weapons Law Violations'
#  'Purse-Snatching' 'Arson' 'Extortion/Blackmail' 'Prostitution'
#  'Kidnapping/Abduction' 'Drug Equipment Violations'
#  'Pornography/Obscene Material' 'Wire Fraud' 'Impersonation'
#  'Assisting or Promoting Prostitution' 'Commercial Sex Acts'
#  'Animal Cruelty' 'Welfare Fraud']
# --------------------------------------------------------------------------------------------
# ...

# %%
# Creating a New Data Frame for a Specific Neighborhood
king_crime = crime.loc[crime['Neighborhood'] == 'King']
king_crime.head()
# Out:
#                                          Address Case Number Crime Against  \
# 5                   5400 BLOCK OF NE MALLORY AVE   17-900129      Property
# 390  5500 BLOCK OF NE MARTIN LUTHER KING JR BLVD     17-9250      Property
# 611                   900 BLOCK OF NE ALBERTA ST   17-900046      Property
# 708                     NE 6TH AVE / NE BEECH ST     17-1842       Society
# 715                  1400 BLOCK OF NE ALBERTA ST   17-900118      Property
#
#     Neighborhood  Number of Records  Occur Date Occur Month Year  Occur Time  \
# 5           King                  1  11/28/2010        11/1/2010        1612
# 390         King                  1  12/10/2016        12/1/2016           0
# 611         King                  1    1/1/2017         1/1/2017         925
# 708         King                  1    1/2/2017         1/1/2017        2144
# 715         King                  1    1/1/2017         1/1/2017        1355
#
# ...

# %%
# Recap
ufo = pd.read_csv('ufoSightings.csv')
ufo.head()
# Out:
# C:\Users\ktorres\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
# ...

# %%
print(ufo.dtypes)
ufo['duration (seconds)'] = pd.to_numeric(ufo['duration (seconds)'])
print('-----------------------------------')
print(ufo.dtypes)
# Out:
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                 object
# longitude               float64
# dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2`"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-4def3ebadafb> in <module>()
#       1 print(ufo.dtypes)
# ----> 2 ufo['duration (seconds)'] = pd.to_numeric(ufo['duration (seconds)'])
# ...
